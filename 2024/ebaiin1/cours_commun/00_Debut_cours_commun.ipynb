# %% [markdown]
# # Ouvrir jupyterlab

# %% [markdown]
# ## Rendez-vous sur le site https://ondemand.cluster.france-bioinformatique.fr/

# %% [markdown]
# ## Renseignez vos identifiants IFB

# %% [markdown]
# ## Sélectionnez "JupyterLab: Core"
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Renseignez les paramètres de votre réservation
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Réservation en attente
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Lancement du JupyterLab
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Vous êtes prêts !
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# # Récupération et lancement des cours communs

# %% [markdown]
# Afin d'avoir en votre possession l'ensemble des cours nécessaires pour le tronc commun, nous vous proposons de copier l'ensemble des TP dans votre espace projet personnel.

# %% [markdown]
# ## Rendez-vous dans votre espace projet
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Ouvrez un terminal
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Tapez la commande suivante
#
# `cp -r /shared/projects/2538_eb3i_n1_2025/cours_commun ./`

# %% [markdown]
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Ouvrez le notebook TP_linux/01_bash_et_la_ligne_de_commande.ipynb
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Ouvrez un terminal et glissez le en dessous pour coder et sauvegarder le cours en même temps
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"

# %% [markdown]
# ## Vous pouvez coder dans le terminal et sauvegarder vos lignes de commande dans le fichier
#
# <img align="center"  src="data:image/png;base64,..." alt="Drawing" style="width: 1000px;"/>"
